# %%
from google.colab.patches import cv2_imshow
import cv2
img = cv2.imread("/content/drive/MyDrive/20daycode/day1/mydog.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>
